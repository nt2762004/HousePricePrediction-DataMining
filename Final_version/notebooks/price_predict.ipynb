# %% [markdown]
# # House Prices Modeling Tutorial
#
# This notebook keeps the original Kaggle House Prices workflow as documentation.
#
# The reusable training code now lives in `src/train.py`.

# %%
from src.train import run_house_pipeline

run_house_pipeline('house-prices-data/train.csv', 'house-prices-data/test.csv', 'submission.csv')
