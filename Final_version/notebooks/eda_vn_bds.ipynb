# %% [markdown]
# # Vietnam Real-Estate EDA Tutorial
#
# This notebook is kept as a tutorial version of the original cleaning and EDA workflow.
#
# The reusable preprocessing logic now lives in `src/preprocess.py`.

# %%
from src.preprocess import load_vn_raw_data, prepare_vn_clean_dataframe, export_vn_clean_data

raw_path = 'VN_BĐS_data/property_cleaned.csv'
clean_path = 'VN_BĐS_data/property_final_clean.csv'

df_raw = load_vn_raw_data(raw_path)
df_clean = prepare_vn_clean_dataframe(df_raw)
export_vn_clean_data(df_clean, clean_path)
