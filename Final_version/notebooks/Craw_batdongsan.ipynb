# %% [markdown]
# # Crawling Notebook Tutorial
#
# This notebook documents the original data-crawling workflow for the Vietnam real-estate dataset.
#
# In the refactored project, the executable code lives in `src/`.

# %%
# Run the VN pipeline from the entry point instead of keeping logic in the notebook.
# python main.py --dataset vn
