# %% [markdown]
# # Vietnam Real-Estate Modeling Tutorial
#
# This notebook documents the original modeling workflow.
#
# The production-ready training pipeline now lives in `src/train.py`.

# %%
from src.train import run_vn_pipeline

run_vn_pipeline('VN_BĐS_data/property_cleaned.csv', 'VN_BĐS_data/property_final_clean.csv')
